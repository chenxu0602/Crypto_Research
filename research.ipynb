# %%
import os, sys
import numpy as np
import pandas as pd
import clickhouse_connect
import matplotlib.pyplot as plt
from collections import defaultdict

import re

# %%
host = 'mini.local'
username = 'admin'
port = 8123
client = clickhouse_connect.get_client(host=host, username=username, port=port)

# %%
stable_coins = [
    "USDCUSDT",
    "BUSDUSDT",
    "USTUSDT",
    "TUSDUSDT",
    "UNIUSDT",
    "LUNAUSDT",
    "FDUSDUSDT",
]

# %%
symbols = client.command('show tables from binance_hist_spot').split('\n')

# %%
N = 20
start_year, end_year = 2021, 2024

data = {}
for symbol in symbols:
    if symbol.upper() in stable_coins: continue
    print(symbol)
    try:
        df = client.query_df(f"select * from binance_hist_spot.{symbol} where open_time >= '{start_year-1}-12-01' and close_time < '{end_year + 1}-01-01'")
    except Exception as e:
        print(f'Could not query {symbol}: {e}')
        continue
    data[symbol] = df
# Out:
# 1inchdownusdt
# 1inchupusdt
# 1inchusdt
# aavedownusdt
# aaveupusdt
# aaveusdt
# acausdt
# achusdt
# acmusdt
# adadownusdt
# adaupusdt
# adausdt
# adxusdt
# aergousdt
# agixusdt
# agldusdt
# aionusdt
# akrousdt
# alcxusdt
# algousdt
# aliceusdt
# alpacausdt
# alphausdt
# alpineusdt
# ambusdt
# ampusdt
# ancusdt
# ankrusdt
# antusdt
# anyusdt
# apeusdt
# api3usdt
# aptusdt
# arbusdt
# ardrusdt
# arkmusdt
# arkusdt
# arpausdt
# arusdt
# asrusdt
# astrusdt
# astusdt
# atausdt
# atmusdt
# atomusdt
# auctionusdt
# audiousdt
# audusdt
# autousdt
# avausdt
# avaxusdt
# axsusdt
# badgerusdt
# bakeusdt
# balusdt
# bandusdt
# barusdt
# batusdt
# bccusdt
# bchabcusdt
# bchdownusdt
# bchsvusdt
# bchupusdt
# bchusdt
# beamusdt
# bearusdt
# belusdt
# betausdt
# bethusdt
# bicousdt
# bifiusdt
# bkrwusdt
# blzusdt
# bnbbearusdt
# bnbbullusdt
# bnbdownusdt
# bnbupusdt
# bnbusdt
# bntusdt
# bnxusdt
# bondusdt
# bswusdt
# btcdownusdt
# btcstusdt
# btcupusdt
# btcusdt
# btgusdt
# btsusdt
# bttcusdt
# bttusdt
# bullusdt
# burgerusdt
# bzrxusdt
# c98usdt
# cakeusdt
# celousdt
# celrusdt
# cfxusdt
# chessusdt
# chrusdt
# chzusdt
# cityusdt
# ckbusdt
# clvusdt
# cocosusdt
# combousdt
# compusdt
# cosusdt
# cotiusdt
# creamusdt
# crvusdt
# ctkusdt
# ctsiusdt
# ctxcusdt
# cvcusdt
# cvpusdt
# cvxusdt
# cyberusdt
# daiusdt
# darusdt
# dashusdt
# datausdt
# dcrusdt
# degousdt
# dentusdt
# dexeusdt
# dfusdt
# dgbusdt
# diausdt
# dntusdt
# dockusdt
# dodousdt
# dogeusdt
# dotdownusdt
# dotupusdt
# dotusdt
# drepusdt
# duskusdt
# dydxusdt
# eduusdt
# egldusdt
# elfusdt
# enjusdt
# ensusdt
# eosbearusdt
# eosbullusdt
# eosdownusdt
# eosupusdt
# eosusdt
# epsusdt
# epxusdt
# erdusdt
# ernusdt
# etcusdt
# ethbearusdt
# ethbullusdt
# ethdownusdt
# ethupusdt
# ethusdt
# eurusdt
# farmusdt
# fetusdt
# fidausdt
# fildownusdt
# filupusdt
# filusdt
# fiousdt
# firousdt
# fisusdt
# flmusdt
# flokiusdt
# flowusdt
# fluxusdt
# forthusdt
# forusdt
# frontusdt
# ftmusdt
# fttusdt
# funusdt
# fxsusdt
# galausdt
# galusdt
# gasusdt
# gbpusdt
# gftusdt
# ghstusdt
# glmrusdt
# glmusdt
# gmtusdt
# gmxusdt
# gnousdt
# gnsusdt
# grtusdt
# gtcusdt
# gtousdt
# gxsusdt
# hardusdt
# hbarusdt
# hcusdt
# hftusdt
# hifiusdt
# highusdt
# hiveusdt
# hntusdt
# hookusdt
# hotusdt
# icpusdt
# icxusdt
# idexusdt
# idusdt
# ilvusdt
# imxusdt
# injusdt
# iostusdt
# iotausdt
# iotxusdt
# irisusdt
# jasmyusdt
# joeusdt
# jstusdt
# juvusdt
# kavausdt
# kdausdt
# keepusdt
# keyusdt
# klayusdt
# kmdusdt
# kncusdt
# kp3rusdt
# ksmusdt
# laziousdt
# ldousdt
# lendusdt
# leverusdt
# linausdt
# linkdownusdt
# linkupusdt
# linkusdt
# litusdt
# lokausdt
# loomusdt
# lptusdt
# lqtyusdt
# lrcusdt
# lskusdt
# ltcdownusdt
# ltcupusdt
# ltcusdt
# ltousdt
# luncusdt
# magicusdt
# manausdt
# maskusdt
# maticusdt
# mavusdt
# mblusdt
# mboxusdt
# mcousdt
# mcusdt
# mdtusdt
# mdxusdt
# mftusdt
# minausdt
# mirusdt
# mithusdt
# mkrusdt
# mlnusdt
# mobusdt
# movrusdt
# mtlusdt
# multiusdt
# nanousdt
# nbsusdt
# nearusdt
# neblusdt
# neousdt
# nexousdt
# nknusdt
# nmrusdt
# npxsusdt
# nulsusdt
# nuusdt
# oaxusdt
# oceanusdt
# ognusdt
# ogusdt
# omgusdt
# omusdt
# oneusdt
# ongusdt
# ontusdt
# ookiusdt
# opusdt
# ornusdt
# osmousdt
# oxtusdt
# paxgusdt
# paxusdt
# pendleusdt
# peopleusdt
# pepeusdt
# perlusdt
# perpusdt
# phausdt
# phbusdt
# plausdt
# pntusdt
# polsusdt
# polyusdt
# polyxusdt
# pondusdt
# portousdt
# powrusdt
# promusdt
# prosusdt
# psgusdt
# pundixusdt
# pyrusdt
# qiusdt
# qkcusdt
# qntusdt
# qtumusdt
# quickusdt
# radusdt
# rampusdt
# rareusdt
# rayusdt
# rdntusdt
# reefusdt
# reiusdt
# renusdt
# repusdt
# requsdt
# rgtusdt
# rifusdt
# rlcusdt
# rndrusdt
# roseusdt
# rplusdt
# rsrusdt
# runeusdt
# rvnusdt
# sandusdt
# santosusdt
# scrtusdt
# scusdt
# seiusdt
# sfpusdt
# shibusdt
# sklusdt
# slpusdt
# sntusdt
# snxusdt
# solusdt
# spellusdt
# srmusdt
# ssvusdt
# steemusdt
# stgusdt
# stmxusdt
# storjusdt
# stormusdt
# stptusdt
# stratusdt
# straxusdt
# stxusdt
# suiusdt
# sunusdt
# superusdt
# susdusdt
# sushidownusdt
# sushiupusdt
# sushiusdt
# sxpdownusdt
# sxpupusdt
# sxpusdt
# synusdt
# sysusdt
# tctusdt
# tfuelusdt
# thetausdt
# tkousdt
# tlmusdt
# tomousdt
# tornusdt
# trbusdt
# tribeusdt
# troyusdt
# truusdt
# trxdownusdt
# trxupusdt
# trxusdt
# tusdt
# tvkusdt
# twtusdt
# uftusdt
# umausdt
# unfiusdt
# unidownusdt
# uniupusdt
# usdpusdt
# usdsbusdt
# usdsusdt
# ustcusdt
# utkusdt
# venusdt
# vetusdt
# vgxusdt
# vibusdt
# vidtusdt
# viteusdt
# voxelusdt
# vthousdt
# wanusdt
# wavesusdt
# waxpusdt
# wbethusdt
# wbtcusdt
# wingusdt
# winusdt
# wldusdt
# wnxmusdt
# woousdt
# wrxusdt
# wtcusdt
# xecusdt
# xemusdt
# xlmdownusdt
# xlmupusdt
# xlmusdt
# xmrusdt
# xnousdt
# xrpbearusdt
# xrpbullusdt
# xrpdownusdt
# xrpupusdt
# xrpusdt
# xtzdownusdt
# xtzupusdt
# xtzusdt
# xvgusdt
# xvsusdt
# xzcusdt
# yfidownusdt
# yfiiusdt
# yfiupusdt
# yfiusdt
# yggusdt
# zecusdt
# zenusdt
# zilusdt
# zrxusdt

# %%
monthly_data = defaultdict(lambda: defaultdict(pd.DataFrame))

for symbol, df in data.items():
    if df.empty: continue
    print(f'No data from {symbol}')
    for year in range(start_year - 1, end_year + 1):
        for month in range(1, 13):
            if year == start_year - 1 and month < 12: continue
            df_month = df.loc[(df['open_time'].dt.year == year) & (df['open_time'].dt.month == month)]
            if df_month.empty: continue
            monthly_data[f'{year:04}-{month:02}'][symbol.upper()] = df_month
# Out:
# No data from 1inchdownusdt
# No data from 1inchupusdt
# No data from 1inchusdt
# No data from aavedownusdt
# No data from aaveupusdt
# No data from aaveusdt
# No data from acausdt
# No data from achusdt
# No data from acmusdt
# No data from adadownusdt
# No data from adaupusdt
# No data from adausdt
# No data from adxusdt
# No data from aergousdt
# No data from agixusdt
# No data from agldusdt
# No data from aionusdt
# No data from akrousdt
# No data from alcxusdt
# No data from algousdt
# No data from aliceusdt
# No data from alpacausdt
# No data from alphausdt
# No data from alpineusdt
# No data from ambusdt
# No data from ampusdt
# No data from ancusdt
# No data from ankrusdt
# No data from antusdt
# No data from anyusdt
# No data from apeusdt
# No data from api3usdt
# No data from aptusdt
# No data from arbusdt
# No data from ardrusdt
# No data from arkmusdt
# No data from arkusdt
# No data from arpausdt
# No data from arusdt
# No data from asrusdt
# No data from astrusdt
# No data from astusdt
# No data from atausdt
# No data from atmusdt
# No data from atomusdt
# No data from auctionusdt
# No data from audiousdt
# No data from audusdt
# No data from autousdt
# No data from avausdt
# No data from avaxusdt
# No data from axsusdt
# No data from badgerusdt
# No data from bakeusdt
# No data from balusdt
# No data from bandusdt
# No data from barusdt
# No data from batusdt
# No data from bchdownusdt
# No data from bchupusdt
# No data from bchusdt
# No data from beamusdt
# No data from belusdt
# No data from betausdt
# No data from bethusdt
# No data from bicousdt
# No data from bifiusdt
# No data from blzusdt
# No data from bnbdownusdt
# No data from bnbupusdt
# No data from bnbusdt
# No data from bntusdt
# No data from bnxusdt
# No data from bondusdt
# No data from bswusdt
# No data from btcdownusdt
# No data from btcstusdt
# No data from btcupusdt
# No data from btcusdt
# No data from btgusdt
# No data from btsusdt
# No data from bttcusdt
# No data from bttusdt
# No data from burgerusdt
# No data from bzrxusdt
# No data from c98usdt
# No data from cakeusdt
# No data from celousdt
# No data from celrusdt
# No data from cfxusdt
# No data from chessusdt
# No data from chrusdt
# No data from chzusdt
# No data from cityusdt
# No data from ckbusdt
# No data from clvusdt
# No data from cocosusdt
# No data from combousdt
# No data from compusdt
# No data from cosusdt
# No data from cotiusdt
# No data from creamusdt
# No data from crvusdt
# No data from ctkusdt
# No data from ctsiusdt
# No data from ctxcusdt
# No data from cvcusdt
# No data from cvpusdt
# No data from cvxusdt
# No data from cyberusdt
# No data from darusdt
# No data from dashusdt
# No data from datausdt
# No data from dcrusdt
# No data from degousdt
# No data from dentusdt
# No data from dexeusdt
# No data from dfusdt
# No data from dgbusdt
# No data from diausdt
# No data from dntusdt
# No data from dockusdt
# No data from dodousdt
# No data from dogeusdt
# No data from dotdownusdt
# No data from dotupusdt
# No data from dotusdt
# No data from drepusdt
# No data from duskusdt
# No data from dydxusdt
# No data from eduusdt
# No data from egldusdt
# No data from elfusdt
# No data from enjusdt
# No data from ensusdt
# No data from eosdownusdt
# No data from eosupusdt
# No data from eosusdt
# No data from epsusdt
# No data from epxusdt
# No data from ernusdt
# No data from etcusdt
# No data from ethdownusdt
# No data from ethupusdt
# No data from ethusdt
# No data from eurusdt
# No data from farmusdt
# No data from fetusdt
# No data from fidausdt
# No data from fildownusdt
# No data from filupusdt
# No data from filusdt
# No data from fiousdt
# No data from firousdt
# No data from fisusdt
# No data from flmusdt
# No data from flokiusdt
# No data from flowusdt
# No data from fluxusdt
# No data from forthusdt
# No data from forusdt
# No data from frontusdt
# No data from ftmusdt
# No data from fttusdt
# No data from funusdt
# No data from fxsusdt
# No data from galausdt
# No data from galusdt
# No data from gasusdt
# No data from gbpusdt
# No data from gftusdt
# No data from ghstusdt
# No data from glmrusdt
# No data from glmusdt
# No data from gmtusdt
# No data from gmxusdt
# No data from gnousdt
# No data from gnsusdt
# No data from grtusdt
# No data from gtcusdt
# No data from gtousdt
# No data from gxsusdt
# No data from hardusdt
# No data from hbarusdt
# No data from hftusdt
# No data from hifiusdt
# No data from highusdt
# No data from hiveusdt
# No data from hntusdt
# No data from hookusdt
# No data from hotusdt
# No data from icpusdt
# No data from icxusdt
# No data from idexusdt
# No data from idusdt
# No data from ilvusdt
# No data from imxusdt
# No data from injusdt
# No data from iostusdt
# No data from iotausdt
# No data from iotxusdt
# No data from irisusdt
# No data from jasmyusdt
# No data from joeusdt
# No data from jstusdt
# No data from juvusdt
# No data from kavausdt
# No data from kdausdt
# No data from keepusdt
# No data from keyusdt
# No data from klayusdt
# No data from kmdusdt
# No data from kncusdt
# No data from kp3rusdt
# No data from ksmusdt
# No data from laziousdt
# No data from ldousdt
# No data from leverusdt
# No data from linausdt
# No data from linkdownusdt
# No data from linkupusdt
# No data from linkusdt
# No data from litusdt
# No data from lokausdt
# No data from loomusdt
# No data from lptusdt
# No data from lqtyusdt
# No data from lrcusdt
# No data from lskusdt
# No data from ltcdownusdt
# No data from ltcupusdt
# No data from ltcusdt
# No data from ltousdt
# No data from luncusdt
# No data from magicusdt
# No data from manausdt
# No data from maskusdt
# No data from maticusdt
# No data from mavusdt
# No data from mblusdt
# No data from mboxusdt
# No data from mcusdt
# No data from mdtusdt
# No data from mdxusdt
# No data from mftusdt
# No data from minausdt
# No data from mirusdt
# No data from mithusdt
# No data from mkrusdt
# No data from mlnusdt
# No data from mobusdt
# No data from movrusdt
# No data from mtlusdt
# No data from multiusdt
# No data from nanousdt
# No data from nbsusdt
# No data from nearusdt
# No data from neblusdt
# No data from neousdt
# No data from nexousdt
# No data from nknusdt
# No data from nmrusdt
# No data from npxsusdt
# No data from nulsusdt
# No data from nuusdt
# No data from oaxusdt
# No data from oceanusdt
# No data from ognusdt
# No data from ogusdt
# No data from omgusdt
# No data from omusdt
# No data from oneusdt
# No data from ongusdt
# No data from ontusdt
# No data from ookiusdt
# No data from opusdt
# No data from ornusdt
# No data from osmousdt
# No data from oxtusdt
# No data from paxgusdt
# No data from paxusdt
# No data from pendleusdt
# No data from peopleusdt
# No data from pepeusdt
# No data from perlusdt
# No data from perpusdt
# No data from phausdt
# No data from phbusdt
# No data from plausdt
# No data from pntusdt
# No data from polsusdt
# No data from polyusdt
# No data from polyxusdt
# No data from pondusdt
# No data from portousdt
# No data from powrusdt
# No data from promusdt
# No data from prosusdt
# No data from psgusdt
# No data from pundixusdt
# No data from pyrusdt
# No data from qiusdt
# No data from qkcusdt
# No data from qntusdt
# No data from qtumusdt
# No data from quickusdt
# No data from radusdt
# No data from rampusdt
# No data from rareusdt
# No data from rayusdt
# No data from rdntusdt
# No data from reefusdt
# No data from reiusdt
# No data from renusdt
# No data from repusdt
# No data from requsdt
# No data from rgtusdt
# No data from rifusdt
# No data from rlcusdt
# No data from rndrusdt
# No data from roseusdt
# No data from rplusdt
# No data from rsrusdt
# No data from runeusdt
# No data from rvnusdt
# No data from sandusdt
# No data from santosusdt
# No data from scrtusdt
# No data from scusdt
# No data from seiusdt
# No data from sfpusdt
# No data from shibusdt
# No data from sklusdt
# No data from slpusdt
# No data from sntusdt
# No data from snxusdt
# No data from solusdt
# No data from spellusdt
# No data from srmusdt
# No data from ssvusdt
# No data from steemusdt
# No data from stgusdt
# No data from stmxusdt
# No data from storjusdt
# No data from stptusdt
# No data from straxusdt
# No data from stxusdt
# No data from suiusdt
# No data from sunusdt
# No data from superusdt
# No data from susdusdt
# No data from sushidownusdt
# No data from sushiupusdt
# No data from sushiusdt
# No data from sxpdownusdt
# No data from sxpupusdt
# No data from sxpusdt
# No data from synusdt
# No data from sysusdt
# No data from tctusdt
# No data from tfuelusdt
# No data from thetausdt
# No data from tkousdt
# No data from tlmusdt
# No data from tomousdt
# No data from tornusdt
# No data from trbusdt
# No data from tribeusdt
# No data from troyusdt
# No data from truusdt
# No data from trxdownusdt
# No data from trxupusdt
# No data from trxusdt
# No data from tusdt
# No data from tvkusdt
# No data from twtusdt
# No data from uftusdt
# No data from umausdt
# No data from unfiusdt
# No data from unidownusdt
# No data from uniupusdt
# No data from usdpusdt
# No data from ustcusdt
# No data from utkusdt
# No data from vetusdt
# No data from vgxusdt
# No data from vibusdt
# No data from vidtusdt
# No data from viteusdt
# No data from voxelusdt
# No data from vthousdt
# No data from wanusdt
# No data from wavesusdt
# No data from waxpusdt
# No data from wbethusdt
# No data from wbtcusdt
# No data from wingusdt
# No data from winusdt
# No data from wldusdt
# No data from wnxmusdt
# No data from woousdt
# No data from wrxusdt
# No data from wtcusdt
# No data from xecusdt
# No data from xemusdt
# No data from xlmdownusdt
# No data from xlmupusdt
# No data from xlmusdt
# No data from xmrusdt
# No data from xnousdt
# No data from xrpdownusdt
# No data from xrpupusdt
# No data from xrpusdt
# No data from xtzdownusdt
# No data from xtzupusdt
# No data from xtzusdt
# No data from xvgusdt
# No data from xvsusdt
# No data from xzcusdt
# No data from yfidownusdt
# No data from yfiiusdt
# No data from yfiupusdt
# No data from yfiusdt
# No data from yggusdt
# No data from zecusdt
# No data from zenusdt
# No data from zilusdt
# No data from zrxusdt

# %%
volumes_by_month = defaultdict(list)
data = monthly_data

for ym in data:
    print(f'Processing {ym}')
    df_btc = data[ym]['BTCUSDT'].set_index('open_time')
    df_eth = data[ym]['ETHUSDT'].set_index('open_time')
    df_daily_volume_btc = df_btc["taker_buy_quote_asset_volume"].resample("1D", closed="left", label="left").sum()
    df_daily_volume_eth = df_eth["taker_buy_quote_asset_volume"].resample("1D", closed="left", label="left").sum()
    df_prc_btc = df_btc['open'].resample('1h', closed='left', label='left').first().ffill().bfill()
    df_prc_eth = df_eth['open'].resample('1h', closed='left', label='left').first().ffill().bfill()
    df_ret_btc = np.log(df_prc_btc).diff()
    df_ret_eth = np.log(df_prc_eth).diff()

    for sym in data[ym]:
        if sym in ['BTCUSDT', 'ETHUSDT']: continue
        df = data[ym][sym].set_index('open_time')
        df_daily_volume = df["taker_buy_quote_asset_volume"].resample("1D", closed="left", label="left").sum()
        df_prc = df['open'].resample('1h', closed='left', label='left').first().ffill().bfill()
        df_ret = np.log(df_prc).diff()
        df_ret_tmp = pd.DataFrame({
            'BTCUSDT': df_ret_btc,
            'ETHUSDT': df_ret_eth,
            sym: df_ret}).fillna(0)
        btc_corr = df_ret_tmp.corr().iloc[0, 2]
        eth_corr = df_ret_tmp.corr().iloc[1, 2]

        vol_btc = df_daily_volume.median() / df_daily_volume_btc.median()
        vol_eth = df_daily_volume.median() / df_daily_volume_eth.median()
        volumes_by_month[ym].append((-df_daily_volume.median(), vol_btc, vol_eth, sym[:-4], btc_corr, eth_corr))

# %%
months = sorted(volumes_by_month.keys())
results = defaultdict(list)

# %%
all_symbols = set()
                    
for i in range(0, len(months)):
    # univ_month = sorted(volumes_by_month[months[i - 1]])
    univ_month = sorted(volumes_by_month[months[i]])
    vols_b  = [x[1] for x in univ_month]
    vols_e  = [x[2] for x in univ_month]
    symbols = [x[3] for x in univ_month]
    btc_cor = [x[4] for x in univ_month]
    eth_cor = [x[5] for x in univ_month]
    univ = []           
    for j in range(len(univ_month)):
        if j == N: break
        univ += f'{symbols[j]}|{vols_b[j]:.2f}|{vols_e[j]:.2f}|{btc_cor[j]:.2f}|{eth_cor[j]:.2f}',
                        
    if len(univ) < N: univ += [''] * (N - len(univ))

    all_symbols |= set(symbols[:N])
    results[months[i] + "-01"] = univ

df = pd.DataFrame(results) 
df.to_csv("univ_by_month_taker.csv", index=False)

with open("univ.csv", 'w') as f:
    for sym in all_symbols:
        if not sym == "":
            f.write(f"{sym}\n")

# %%
df
# Out:
#                        2020-12-01                  2021-01-01  \
# 0         XRP|0.23|0.72|0.44|0.52  BUSD|0.10|0.17|-0.35|-0.35
# 1         LTC|0.12|0.36|0.77|0.81     DOT|0.09|0.15|0.53|0.56
# 2           GRT|0.09|0.28|nan|nan     LTC|0.08|0.13|0.77|0.81
# 3        BUSD|0.09|0.27|0.05|0.05     XRP|0.07|0.11|0.42|0.43
# 4         BCH|0.05|0.15|0.69|0.75    LINK|0.07|0.11|0.60|0.70
# 5        LINK|0.04|0.13|0.57|0.80     ADA|0.06|0.10|0.63|0.68
# 6         BNB|0.04|0.12|0.59|0.66     BCH|0.04|0.07|0.68|0.73
# 7         ADA|0.04|0.12|0.65|0.76     XLM|0.04|0.06|0.41|0.45
# 8         1INCH|0.04|0.11|nan|nan  USDC|0.04|0.06|-0.30|-0.34
# 9      USDC|0.03|0.09|-0.14|-0.13     BNB|0.04|0.06|0.66|0.70
# 10        XLM|0.03|0.09|0.57|0.69     EOS|0.02|0.04|0.57|0.61
# 11         REEF|0.03|0.08|nan|nan     UNI|0.02|0.03|0.51|0.66
# 12        YFI|0.03|0.08|0.51|0.68   SUSHI|0.02|0.03|0.53|0.70
# 13        EOS|0.02|0.08|0.62|0.74     GRT|0.02|0.03|0.44|0.42
# 14      SUSHI|0.02|0.06|0.47|0.64     VET|0.02|0.03|0.65|0.65
# 15        DOT|0.02|0.05|0.50|0.61     YFI|0.02|0.03|0.57|0.67
# 16        TRX|0.02|0.05|0.66|0.79     CRV|0.02|0.03|0.40|0.48
# 17      XRPUP|0.02|0.05|0.46|0.53     TRX|0.02|0.03|0.46|0.47
# 18  XRPDOWN|0.01|0.04|-0.48|-0.56    AAVE|0.02|0.02|0.56|0.71
# 19        VET|0.01|0.04|0.59|0.68    EUR|0.01|0.02|-0.09|0.05
#
#                     2021-02-01                  2021-03-01  \
# 0      BNB|0.22|0.46|0.52|0.54     BNB|0.23|0.63|0.69|0.69
# 1   BUSD|0.20|0.42|-0.18|-0.19  BUSD|0.20|0.53|-0.09|-0.09
# 2      ADA|0.17|0.36|0.47|0.56     ADA|0.12|0.33|0.47|0.45
# 3      XRP|0.15|0.31|0.41|0.41     CHZ|0.11|0.29|0.17|0.17
# 4      DOT|0.12|0.25|0.61|0.68     XRP|0.08|0.22|0.54|0.55
# 5     DOGE|0.11|0.24|0.24|0.27     DOT|0.08|0.21|0.68|0.67
# 6      LTC|0.08|0.18|0.75|0.77     ENJ|0.05|0.13|0.27|0.25
# 7      EOS|0.05|0.11|0.58|0.66     LTC|0.05|0.13|0.77|0.78
# 8     LINK|0.05|0.11|0.64|0.78   THETA|0.05|0.13|0.33|0.32
